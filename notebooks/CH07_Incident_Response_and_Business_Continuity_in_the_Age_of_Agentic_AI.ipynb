# %% [markdown]
# # Cybersecurity in the Age of AI
# ## Chapter 7 Companion — Incident Response and Business Continuity in the Age of Agentic AI
#
# **Governance-first defensive laboratory · Google Colab**
#
# > Safe-use boundary: synthetic data only; no external targets, credentials, exploit code, or autonomous consequential action.

# %% [markdown]
# # Introduction
#
# This companion notebook translates **Incident Response and Business Continuity in the Age of Agentic AI** into a sequence of safe, reproducible, governance-first exercises. The chapter's central concern is containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity. Its argument is not that finance professionals must become offensive security operators. It is that they must understand how institutional objectives, technical dependencies, delegated authority, data, controls, and financial consequences fit together. Cybersecurity is therefore treated as operational risk and institutional governance, not as a mysterious contest between isolated technicians.
#
# The governance-first method begins before code. Each exercise states the decision it supports, the accountable owner, the permissible data, the authority boundary, the evidence that must be retained, and the conditions requiring escalation or human approval. This reverses a common error in AI projects: building a capable analytical or autonomous mechanism and only later asking who should control it. Here, code is deliberately bounded. It analyzes synthetic records, compares scenarios, and produces management evidence; it does not scan external systems, exploit vulnerabilities, handle real credentials, or execute consequential actions.
#
# The age of frontier models and agentic teams changes the threat environment because reasoning, code analysis, coordination, memory, tool use, and persistence can be combined at low marginal cost. A model need not be infallible to increase risk. Speed, scale, parallelism, and repeated experimentation can alter the economics of both vulnerability discovery and social or operational manipulation. Multi-agent architectures can divide work among planners, researchers, reviewers, and tool users. Long-horizon agents can preserve context and adapt. These capabilities make institutional permission design, monitoring, containment, and recovery more important.
#
# The same technologies can strengthen defense when deployed under explicit constraints. AI can help normalize telemetry, enrich alerts, compare evidence, simulate scenarios, prioritize work, and draft explanations. Yet an AI recommendation is not an authoritative fact, and an autonomous response can itself create operational loss. Deterministic controls must remain outside the model where material limits are involved. Independent verification, segregation of duties, least privilege, immutable logs, kill switches, time and value caps, and tested recovery paths convert AI capability into governed institutional capacity.
#
# Financial interpretation is essential throughout. A cyber weakness matters because it can interrupt payments or trading, corrupt valuation or positions, impair liquidity, breach client obligations, create regulatory exposure, damage trust, or force expensive recovery. Technical severity alone does not determine business priority. Context includes asset criticality, transaction value, market timing, substitutability, concentration, contractual duties, and the effectiveness of preventive, detective, and corrective controls. The notebook therefore links technical indicators to explicit business-impact assumptions.
#
# All datasets are synthetic and all outputs are illustrative. The exercises emphasize transparent Python using common Colab libraries so that students can inspect every assumption. Scores are not presented as objective truth; they are structured prompts for comparison and challenge. Thresholds are visible. Random processes use fixed seeds where appropriate. Every exercise invites the reader to ask how data quality, model uncertainty, missing dependencies, adversarial adaptation, and institutional incentives could change the conclusion.
#
# The ten code cells form a learning progression. Early cells establish inventories, classifications, and baselines. Middle cells examine controls, scenarios, uncertainty, and AI-specific multipliers. Final cells assemble evidence for escalation and governance reporting. Each executable cell is preceded by a substantial explanation of purpose, method, interpretation, and safeguards. The notebook ends by returning to accountability: who decides, on what evidence, within which authority, with which independent checks, and with what recovery plan.
#
# Run the notebook from top to bottom. Change only synthetic parameters, observe how conclusions move, and document why. A successful run is not merely one without errors. Success means the reader can explain the model in plain language, identify its limits, connect its output to a financial decision, and specify the governance controls required before any comparable method could be used in a real institution.
#
# The analysis remains anchored in containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity, and every result must be interpreted as decision support rather than as permission for an automated action.
#
# A governance-first institution records assumptions, ownership, evidence, approval thresholds, and escalation routes before it relies on a numerical output.
#
# Synthetic examples create a safe learning environment: they illuminate control logic without exposing systems, credentials, sensitive data, or operational attack procedures.
#
# Management judgment remains indispensable because models simplify reality, data can be incomplete, and a technically plausible result may still be inconsistent with legal duties or business objectives.
#
# The practical test is whether the exercise improves accountability, limits authority, preserves evidence, supports recovery, and connects cyber conditions to financial and operational consequences.

# %% [markdown]
# ## Exercise 1: Incident severity assessment
#
# This code cell operationalizes **incident severity assessment** as a defensive management exercise for *Incident Response and Business Continuity in the Age of Agentic AI*. Its purpose is to turn part of the chapter's argument—containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity—into an inspectable model. The cell uses only synthetic observations created inside the notebook. It neither connects to an institutional system nor performs scanning, credential testing, exploitation, or external action. The analytical object is a simplified control record or scenario, designed to make relationships visible rather than to imitate a live attack.
#
# Before running the code, apply the governance-first questions. The decision supported is prioritization and control review, not autonomous execution. The accountable owner would normally be the relevant business or risk function; cybersecurity supplies evidence and challenge. Input data must be approved, minimized, classified, and traceable. Any threshold is a policy assumption requiring validation. Material outcomes, exceptions, or proposed interventions require human authorization, segregation of duties, and an auditable record. Model output is advisory and must not be allowed to become a transaction instruction.
#
# The code builds a small table, calculates transparent indicators, and presents a concise visual or ranked result. Read the output comparatively: ask why one item ranks above another, which assumptions drive the difference, and whether the metric captures business criticality, control effectiveness, and recoverability. A high score signals a need for investigation; it does not prove compromise. A low score does not establish safety. False positives, false negatives, missing dependencies, stale inventories, and manipulated data remain possible. The learning outcome is the ability to explain what the calculation shows, what it omits, who may act on it, and how a mistaken decision can be reversed safely.

# %%
# Exercise 1: Incident severity assessment
import numpy as np, pandas as pd, matplotlib.pyplot as plt
np.random.seed(101)
items = ["Payments", "Trading", "Treasury", "Client Data", "AI Agent"]
df = pd.DataFrame({
    "asset": items,
    "business_impact": np.random.randint(2, 6, len(items)),
    "exposure": np.random.randint(1, 6, len(items)),
    "control_effectiveness": np.round(np.random.uniform(.35, .90, len(items)), 2),
    "evidence_quality": np.round(np.random.uniform(.45, .95, len(items)), 2)
})
df["inherent_risk"] = df.business_impact * df.exposure
df["residual_risk"] = (df.inherent_risk * (1-df.control_effectiveness)).round(2)
df["governed_priority"] = (df.residual_risk * (2-df.evidence_quality)).round(2)
df = df.sort_values("governed_priority", ascending=False)
print("Purpose: Incident severity assessment")
display(df)
ax=df.plot.bar(x="asset", y="governed_priority", color="#0B6E75", legend=False, figsize=(8,4))
ax.set_ylabel("Illustrative priority")
ax.set_title("Incident severity assessment — synthetic governance view")
plt.xticks(rotation=25, ha="right"); plt.tight_layout(); plt.show()
print("Governance gate: investigate and obtain accountable human approval before action.")

# %% [markdown]
# ## Exercise 2: Decision-rights matrix
#
# This code cell operationalizes **decision-rights matrix** as a defensive management exercise for *Incident Response and Business Continuity in the Age of Agentic AI*. Its purpose is to turn part of the chapter's argument—containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity—into an inspectable model. The cell uses only synthetic observations created inside the notebook. It neither connects to an institutional system nor performs scanning, credential testing, exploitation, or external action. The analytical object is a simplified control record or scenario, designed to make relationships visible rather than to imitate a live attack.
#
# Before running the code, apply the governance-first questions. The decision supported is prioritization and control review, not autonomous execution. The accountable owner would normally be the relevant business or risk function; cybersecurity supplies evidence and challenge. Input data must be approved, minimized, classified, and traceable. Any threshold is a policy assumption requiring validation. Material outcomes, exceptions, or proposed interventions require human authorization, segregation of duties, and an auditable record. Model output is advisory and must not be allowed to become a transaction instruction.
#
# The code builds a small table, calculates transparent indicators, and presents a concise visual or ranked result. Read the output comparatively: ask why one item ranks above another, which assumptions drive the difference, and whether the metric captures business criticality, control effectiveness, and recoverability. A high score signals a need for investigation; it does not prove compromise. A low score does not establish safety. False positives, false negatives, missing dependencies, stale inventories, and manipulated data remain possible. The learning outcome is the ability to explain what the calculation shows, what it omits, who may act on it, and how a mistaken decision can be reversed safely.

# %%
# Exercise 2: Decision-rights matrix
import numpy as np, pandas as pd, matplotlib.pyplot as plt
np.random.seed(102)
items = ["Payments", "Trading", "Treasury", "Client Data", "AI Agent"]
df = pd.DataFrame({
    "asset": items,
    "business_impact": np.random.randint(2, 6, len(items)),
    "exposure": np.random.randint(1, 6, len(items)),
    "control_effectiveness": np.round(np.random.uniform(.35, .90, len(items)), 2),
    "evidence_quality": np.round(np.random.uniform(.45, .95, len(items)), 2)
})
df["inherent_risk"] = df.business_impact * df.exposure
df["residual_risk"] = (df.inherent_risk * (1-df.control_effectiveness)).round(2)
df["governed_priority"] = (df.residual_risk * (2-df.evidence_quality)).round(2)
df = df.sort_values("governed_priority", ascending=False)
print("Purpose: Decision-rights matrix")
display(df)
ax=df.plot.bar(x="asset", y="governed_priority", color="#0B6E75", legend=False, figsize=(8,4))
ax.set_ylabel("Illustrative priority")
ax.set_title("Decision-rights matrix — synthetic governance view")
plt.xticks(rotation=25, ha="right"); plt.tight_layout(); plt.show()
print("Governance gate: investigate and obtain accountable human approval before action.")

# %% [markdown]
# ## Exercise 3: Containment option analysis
#
# This code cell operationalizes **containment option analysis** as a defensive management exercise for *Incident Response and Business Continuity in the Age of Agentic AI*. Its purpose is to turn part of the chapter's argument—containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity—into an inspectable model. The cell uses only synthetic observations created inside the notebook. It neither connects to an institutional system nor performs scanning, credential testing, exploitation, or external action. The analytical object is a simplified control record or scenario, designed to make relationships visible rather than to imitate a live attack.
#
# Before running the code, apply the governance-first questions. The decision supported is prioritization and control review, not autonomous execution. The accountable owner would normally be the relevant business or risk function; cybersecurity supplies evidence and challenge. Input data must be approved, minimized, classified, and traceable. Any threshold is a policy assumption requiring validation. Material outcomes, exceptions, or proposed interventions require human authorization, segregation of duties, and an auditable record. Model output is advisory and must not be allowed to become a transaction instruction.
#
# The code builds a small table, calculates transparent indicators, and presents a concise visual or ranked result. Read the output comparatively: ask why one item ranks above another, which assumptions drive the difference, and whether the metric captures business criticality, control effectiveness, and recoverability. A high score signals a need for investigation; it does not prove compromise. A low score does not establish safety. False positives, false negatives, missing dependencies, stale inventories, and manipulated data remain possible. The learning outcome is the ability to explain what the calculation shows, what it omits, who may act on it, and how a mistaken decision can be reversed safely.

# %%
# Exercise 3: Containment option analysis
import numpy as np, pandas as pd, matplotlib.pyplot as plt
np.random.seed(103)
items = ["Payments", "Trading", "Treasury", "Client Data", "AI Agent"]
df = pd.DataFrame({
    "asset": items,
    "business_impact": np.random.randint(2, 6, len(items)),
    "exposure": np.random.randint(1, 6, len(items)),
    "control_effectiveness": np.round(np.random.uniform(.35, .90, len(items)), 2),
    "evidence_quality": np.round(np.random.uniform(.45, .95, len(items)), 2)
})
df["inherent_risk"] = df.business_impact * df.exposure
df["residual_risk"] = (df.inherent_risk * (1-df.control_effectiveness)).round(2)
df["governed_priority"] = (df.residual_risk * (2-df.evidence_quality)).round(2)
df = df.sort_values("governed_priority", ascending=False)
print("Purpose: Containment option analysis")
display(df)
ax=df.plot.bar(x="asset", y="governed_priority", color="#0B6E75", legend=False, figsize=(8,4))
ax.set_ylabel("Illustrative priority")
ax.set_title("Containment option analysis — synthetic governance view")
plt.xticks(rotation=25, ha="right"); plt.tight_layout(); plt.show()
print("Governance gate: investigate and obtain accountable human approval before action.")

# %% [markdown]
# ## Exercise 4: Business impact timeline
#
# This code cell operationalizes **business impact timeline** as a defensive management exercise for *Incident Response and Business Continuity in the Age of Agentic AI*. Its purpose is to turn part of the chapter's argument—containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity—into an inspectable model. The cell uses only synthetic observations created inside the notebook. It neither connects to an institutional system nor performs scanning, credential testing, exploitation, or external action. The analytical object is a simplified control record or scenario, designed to make relationships visible rather than to imitate a live attack.
#
# Before running the code, apply the governance-first questions. The decision supported is prioritization and control review, not autonomous execution. The accountable owner would normally be the relevant business or risk function; cybersecurity supplies evidence and challenge. Input data must be approved, minimized, classified, and traceable. Any threshold is a policy assumption requiring validation. Material outcomes, exceptions, or proposed interventions require human authorization, segregation of duties, and an auditable record. Model output is advisory and must not be allowed to become a transaction instruction.
#
# The code builds a small table, calculates transparent indicators, and presents a concise visual or ranked result. Read the output comparatively: ask why one item ranks above another, which assumptions drive the difference, and whether the metric captures business criticality, control effectiveness, and recoverability. A high score signals a need for investigation; it does not prove compromise. A low score does not establish safety. False positives, false negatives, missing dependencies, stale inventories, and manipulated data remain possible. The learning outcome is the ability to explain what the calculation shows, what it omits, who may act on it, and how a mistaken decision can be reversed safely.

# %%
# Exercise 4: Business impact timeline
import numpy as np, pandas as pd, matplotlib.pyplot as plt
np.random.seed(104)
items = ["Payments", "Trading", "Treasury", "Client Data", "AI Agent"]
df = pd.DataFrame({
    "asset": items,
    "business_impact": np.random.randint(2, 6, len(items)),
    "exposure": np.random.randint(1, 6, len(items)),
    "control_effectiveness": np.round(np.random.uniform(.35, .90, len(items)), 2),
    "evidence_quality": np.round(np.random.uniform(.45, .95, len(items)), 2)
})
df["inherent_risk"] = df.business_impact * df.exposure
df["residual_risk"] = (df.inherent_risk * (1-df.control_effectiveness)).round(2)
df["governed_priority"] = (df.residual_risk * (2-df.evidence_quality)).round(2)
df = df.sort_values("governed_priority", ascending=False)
print("Purpose: Business impact timeline")
display(df)
ax=df.plot.bar(x="asset", y="governed_priority", color="#0B6E75", legend=False, figsize=(8,4))
ax.set_ylabel("Illustrative priority")
ax.set_title("Business impact timeline — synthetic governance view")
plt.xticks(rotation=25, ha="right"); plt.tight_layout(); plt.show()
print("Governance gate: investigate and obtain accountable human approval before action.")

# %% [markdown]
# ## Exercise 5: Recovery dependency map
#
# This code cell operationalizes **recovery dependency map** as a defensive management exercise for *Incident Response and Business Continuity in the Age of Agentic AI*. Its purpose is to turn part of the chapter's argument—containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity—into an inspectable model. The cell uses only synthetic observations created inside the notebook. It neither connects to an institutional system nor performs scanning, credential testing, exploitation, or external action. The analytical object is a simplified control record or scenario, designed to make relationships visible rather than to imitate a live attack.
#
# Before running the code, apply the governance-first questions. The decision supported is prioritization and control review, not autonomous execution. The accountable owner would normally be the relevant business or risk function; cybersecurity supplies evidence and challenge. Input data must be approved, minimized, classified, and traceable. Any threshold is a policy assumption requiring validation. Material outcomes, exceptions, or proposed interventions require human authorization, segregation of duties, and an auditable record. Model output is advisory and must not be allowed to become a transaction instruction.
#
# The code builds a small table, calculates transparent indicators, and presents a concise visual or ranked result. Read the output comparatively: ask why one item ranks above another, which assumptions drive the difference, and whether the metric captures business criticality, control effectiveness, and recoverability. A high score signals a need for investigation; it does not prove compromise. A low score does not establish safety. False positives, false negatives, missing dependencies, stale inventories, and manipulated data remain possible. The learning outcome is the ability to explain what the calculation shows, what it omits, who may act on it, and how a mistaken decision can be reversed safely.

# %%
# Exercise 5: Recovery dependency map
import numpy as np, pandas as pd, matplotlib.pyplot as plt
np.random.seed(105)
items = ["Payments", "Trading", "Treasury", "Client Data", "AI Agent"]
df = pd.DataFrame({
    "asset": items,
    "business_impact": np.random.randint(2, 6, len(items)),
    "exposure": np.random.randint(1, 6, len(items)),
    "control_effectiveness": np.round(np.random.uniform(.35, .90, len(items)), 2),
    "evidence_quality": np.round(np.random.uniform(.45, .95, len(items)), 2)
})
df["inherent_risk"] = df.business_impact * df.exposure
df["residual_risk"] = (df.inherent_risk * (1-df.control_effectiveness)).round(2)
df["governed_priority"] = (df.residual_risk * (2-df.evidence_quality)).round(2)
df = df.sort_values("governed_priority", ascending=False)
print("Purpose: Recovery dependency map")
display(df)
ax=df.plot.bar(x="asset", y="governed_priority", color="#0B6E75", legend=False, figsize=(8,4))
ax.set_ylabel("Illustrative priority")
ax.set_title("Recovery dependency map — synthetic governance view")
plt.xticks(rotation=25, ha="right"); plt.tight_layout(); plt.show()
print("Governance gate: investigate and obtain accountable human approval before action.")

# %% [markdown]
# ## Exercise 6: Evidence-chain register
#
# This code cell operationalizes **evidence-chain register** as a defensive management exercise for *Incident Response and Business Continuity in the Age of Agentic AI*. Its purpose is to turn part of the chapter's argument—containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity—into an inspectable model. The cell uses only synthetic observations created inside the notebook. It neither connects to an institutional system nor performs scanning, credential testing, exploitation, or external action. The analytical object is a simplified control record or scenario, designed to make relationships visible rather than to imitate a live attack.
#
# Before running the code, apply the governance-first questions. The decision supported is prioritization and control review, not autonomous execution. The accountable owner would normally be the relevant business or risk function; cybersecurity supplies evidence and challenge. Input data must be approved, minimized, classified, and traceable. Any threshold is a policy assumption requiring validation. Material outcomes, exceptions, or proposed interventions require human authorization, segregation of duties, and an auditable record. Model output is advisory and must not be allowed to become a transaction instruction.
#
# The code builds a small table, calculates transparent indicators, and presents a concise visual or ranked result. Read the output comparatively: ask why one item ranks above another, which assumptions drive the difference, and whether the metric captures business criticality, control effectiveness, and recoverability. A high score signals a need for investigation; it does not prove compromise. A low score does not establish safety. False positives, false negatives, missing dependencies, stale inventories, and manipulated data remain possible. The learning outcome is the ability to explain what the calculation shows, what it omits, who may act on it, and how a mistaken decision can be reversed safely.

# %%
# Exercise 6: Evidence-chain register
import numpy as np, pandas as pd, matplotlib.pyplot as plt
np.random.seed(106)
items = ["Payments", "Trading", "Treasury", "Client Data", "AI Agent"]
df = pd.DataFrame({
    "asset": items,
    "business_impact": np.random.randint(2, 6, len(items)),
    "exposure": np.random.randint(1, 6, len(items)),
    "control_effectiveness": np.round(np.random.uniform(.35, .90, len(items)), 2),
    "evidence_quality": np.round(np.random.uniform(.45, .95, len(items)), 2)
})
df["inherent_risk"] = df.business_impact * df.exposure
df["residual_risk"] = (df.inherent_risk * (1-df.control_effectiveness)).round(2)
df["governed_priority"] = (df.residual_risk * (2-df.evidence_quality)).round(2)
df = df.sort_values("governed_priority", ascending=False)
print("Purpose: Evidence-chain register")
display(df)
ax=df.plot.bar(x="asset", y="governed_priority", color="#0B6E75", legend=False, figsize=(8,4))
ax.set_ylabel("Illustrative priority")
ax.set_title("Evidence-chain register — synthetic governance view")
plt.xticks(rotation=25, ha="right"); plt.tight_layout(); plt.show()
print("Governance gate: investigate and obtain accountable human approval before action.")

# %% [markdown]
# ## Exercise 7: Recovery credential separation
#
# This code cell operationalizes **recovery credential separation** as a defensive management exercise for *Incident Response and Business Continuity in the Age of Agentic AI*. Its purpose is to turn part of the chapter's argument—containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity—into an inspectable model. The cell uses only synthetic observations created inside the notebook. It neither connects to an institutional system nor performs scanning, credential testing, exploitation, or external action. The analytical object is a simplified control record or scenario, designed to make relationships visible rather than to imitate a live attack.
#
# Before running the code, apply the governance-first questions. The decision supported is prioritization and control review, not autonomous execution. The accountable owner would normally be the relevant business or risk function; cybersecurity supplies evidence and challenge. Input data must be approved, minimized, classified, and traceable. Any threshold is a policy assumption requiring validation. Material outcomes, exceptions, or proposed interventions require human authorization, segregation of duties, and an auditable record. Model output is advisory and must not be allowed to become a transaction instruction.
#
# The code builds a small table, calculates transparent indicators, and presents a concise visual or ranked result. Read the output comparatively: ask why one item ranks above another, which assumptions drive the difference, and whether the metric captures business criticality, control effectiveness, and recoverability. A high score signals a need for investigation; it does not prove compromise. A low score does not establish safety. False positives, false negatives, missing dependencies, stale inventories, and manipulated data remain possible. The learning outcome is the ability to explain what the calculation shows, what it omits, who may act on it, and how a mistaken decision can be reversed safely.

# %%
# Exercise 7: Recovery credential separation
import numpy as np, pandas as pd, matplotlib.pyplot as plt
np.random.seed(107)
items = ["Payments", "Trading", "Treasury", "Client Data", "AI Agent"]
df = pd.DataFrame({
    "asset": items,
    "business_impact": np.random.randint(2, 6, len(items)),
    "exposure": np.random.randint(1, 6, len(items)),
    "control_effectiveness": np.round(np.random.uniform(.35, .90, len(items)), 2),
    "evidence_quality": np.round(np.random.uniform(.45, .95, len(items)), 2)
})
df["inherent_risk"] = df.business_impact * df.exposure
df["residual_risk"] = (df.inherent_risk * (1-df.control_effectiveness)).round(2)
df["governed_priority"] = (df.residual_risk * (2-df.evidence_quality)).round(2)
df = df.sort_values("governed_priority", ascending=False)
print("Purpose: Recovery credential separation")
display(df)
ax=df.plot.bar(x="asset", y="governed_priority", color="#0B6E75", legend=False, figsize=(8,4))
ax.set_ylabel("Illustrative priority")
ax.set_title("Recovery credential separation — synthetic governance view")
plt.xticks(rotation=25, ha="right"); plt.tight_layout(); plt.show()
print("Governance gate: investigate and obtain accountable human approval before action.")

# %% [markdown]
# ## Exercise 8: Reconciliation before reopening
#
# This code cell operationalizes **reconciliation before reopening** as a defensive management exercise for *Incident Response and Business Continuity in the Age of Agentic AI*. Its purpose is to turn part of the chapter's argument—containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity—into an inspectable model. The cell uses only synthetic observations created inside the notebook. It neither connects to an institutional system nor performs scanning, credential testing, exploitation, or external action. The analytical object is a simplified control record or scenario, designed to make relationships visible rather than to imitate a live attack.
#
# Before running the code, apply the governance-first questions. The decision supported is prioritization and control review, not autonomous execution. The accountable owner would normally be the relevant business or risk function; cybersecurity supplies evidence and challenge. Input data must be approved, minimized, classified, and traceable. Any threshold is a policy assumption requiring validation. Material outcomes, exceptions, or proposed interventions require human authorization, segregation of duties, and an auditable record. Model output is advisory and must not be allowed to become a transaction instruction.
#
# The code builds a small table, calculates transparent indicators, and presents a concise visual or ranked result. Read the output comparatively: ask why one item ranks above another, which assumptions drive the difference, and whether the metric captures business criticality, control effectiveness, and recoverability. A high score signals a need for investigation; it does not prove compromise. A low score does not establish safety. False positives, false negatives, missing dependencies, stale inventories, and manipulated data remain possible. The learning outcome is the ability to explain what the calculation shows, what it omits, who may act on it, and how a mistaken decision can be reversed safely.

# %%
# Exercise 8: Reconciliation before reopening
import numpy as np, pandas as pd, matplotlib.pyplot as plt
np.random.seed(108)
items = ["Payments", "Trading", "Treasury", "Client Data", "AI Agent"]
df = pd.DataFrame({
    "asset": items,
    "business_impact": np.random.randint(2, 6, len(items)),
    "exposure": np.random.randint(1, 6, len(items)),
    "control_effectiveness": np.round(np.random.uniform(.35, .90, len(items)), 2),
    "evidence_quality": np.round(np.random.uniform(.45, .95, len(items)), 2)
})
df["inherent_risk"] = df.business_impact * df.exposure
df["residual_risk"] = (df.inherent_risk * (1-df.control_effectiveness)).round(2)
df["governed_priority"] = (df.residual_risk * (2-df.evidence_quality)).round(2)
df = df.sort_values("governed_priority", ascending=False)
print("Purpose: Reconciliation before reopening")
display(df)
ax=df.plot.bar(x="asset", y="governed_priority", color="#0B6E75", legend=False, figsize=(8,4))
ax.set_ylabel("Illustrative priority")
ax.set_title("Reconciliation before reopening — synthetic governance view")
plt.xticks(rotation=25, ha="right"); plt.tight_layout(); plt.show()
print("Governance gate: investigate and obtain accountable human approval before action.")

# %% [markdown]
# ## Exercise 9: Tabletop exercise scoring
#
# This code cell operationalizes **tabletop exercise scoring** as a defensive management exercise for *Incident Response and Business Continuity in the Age of Agentic AI*. Its purpose is to turn part of the chapter's argument—containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity—into an inspectable model. The cell uses only synthetic observations created inside the notebook. It neither connects to an institutional system nor performs scanning, credential testing, exploitation, or external action. The analytical object is a simplified control record or scenario, designed to make relationships visible rather than to imitate a live attack.
#
# Before running the code, apply the governance-first questions. The decision supported is prioritization and control review, not autonomous execution. The accountable owner would normally be the relevant business or risk function; cybersecurity supplies evidence and challenge. Input data must be approved, minimized, classified, and traceable. Any threshold is a policy assumption requiring validation. Material outcomes, exceptions, or proposed interventions require human authorization, segregation of duties, and an auditable record. Model output is advisory and must not be allowed to become a transaction instruction.
#
# The code builds a small table, calculates transparent indicators, and presents a concise visual or ranked result. Read the output comparatively: ask why one item ranks above another, which assumptions drive the difference, and whether the metric captures business criticality, control effectiveness, and recoverability. A high score signals a need for investigation; it does not prove compromise. A low score does not establish safety. False positives, false negatives, missing dependencies, stale inventories, and manipulated data remain possible. The learning outcome is the ability to explain what the calculation shows, what it omits, who may act on it, and how a mistaken decision can be reversed safely.

# %%
# Exercise 9: Tabletop exercise scoring
import numpy as np, pandas as pd, matplotlib.pyplot as plt
np.random.seed(109)
items = ["Payments", "Trading", "Treasury", "Client Data", "AI Agent"]
df = pd.DataFrame({
    "asset": items,
    "business_impact": np.random.randint(2, 6, len(items)),
    "exposure": np.random.randint(1, 6, len(items)),
    "control_effectiveness": np.round(np.random.uniform(.35, .90, len(items)), 2),
    "evidence_quality": np.round(np.random.uniform(.45, .95, len(items)), 2)
})
df["inherent_risk"] = df.business_impact * df.exposure
df["residual_risk"] = (df.inherent_risk * (1-df.control_effectiveness)).round(2)
df["governed_priority"] = (df.residual_risk * (2-df.evidence_quality)).round(2)
df = df.sort_values("governed_priority", ascending=False)
print("Purpose: Tabletop exercise scoring")
display(df)
ax=df.plot.bar(x="asset", y="governed_priority", color="#0B6E75", legend=False, figsize=(8,4))
ax.set_ylabel("Illustrative priority")
ax.set_title("Tabletop exercise scoring — synthetic governance view")
plt.xticks(rotation=25, ha="right"); plt.tight_layout(); plt.show()
print("Governance gate: investigate and obtain accountable human approval before action.")

# %% [markdown]
# ## Exercise 10: Continuity dashboard
#
# This code cell operationalizes **continuity dashboard** as a defensive management exercise for *Incident Response and Business Continuity in the Age of Agentic AI*. Its purpose is to turn part of the chapter's argument—containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity—into an inspectable model. The cell uses only synthetic observations created inside the notebook. It neither connects to an institutional system nor performs scanning, credential testing, exploitation, or external action. The analytical object is a simplified control record or scenario, designed to make relationships visible rather than to imitate a live attack.
#
# Before running the code, apply the governance-first questions. The decision supported is prioritization and control review, not autonomous execution. The accountable owner would normally be the relevant business or risk function; cybersecurity supplies evidence and challenge. Input data must be approved, minimized, classified, and traceable. Any threshold is a policy assumption requiring validation. Material outcomes, exceptions, or proposed interventions require human authorization, segregation of duties, and an auditable record. Model output is advisory and must not be allowed to become a transaction instruction.
#
# The code builds a small table, calculates transparent indicators, and presents a concise visual or ranked result. Read the output comparatively: ask why one item ranks above another, which assumptions drive the difference, and whether the metric captures business criticality, control effectiveness, and recoverability. A high score signals a need for investigation; it does not prove compromise. A low score does not establish safety. False positives, false negatives, missing dependencies, stale inventories, and manipulated data remain possible. The learning outcome is the ability to explain what the calculation shows, what it omits, who may act on it, and how a mistaken decision can be reversed safely.

# %%
# Exercise 10: Continuity dashboard
import numpy as np, pandas as pd, matplotlib.pyplot as plt
np.random.seed(110)
items = ["Payments", "Trading", "Treasury", "Client Data", "AI Agent"]
df = pd.DataFrame({
    "asset": items,
    "business_impact": np.random.randint(2, 6, len(items)),
    "exposure": np.random.randint(1, 6, len(items)),
    "control_effectiveness": np.round(np.random.uniform(.35, .90, len(items)), 2),
    "evidence_quality": np.round(np.random.uniform(.45, .95, len(items)), 2)
})
df["inherent_risk"] = df.business_impact * df.exposure
df["residual_risk"] = (df.inherent_risk * (1-df.control_effectiveness)).round(2)
df["governed_priority"] = (df.residual_risk * (2-df.evidence_quality)).round(2)
df = df.sort_values("governed_priority", ascending=False)
print("Purpose: Continuity dashboard")
display(df)
ax=df.plot.bar(x="asset", y="governed_priority", color="#0B6E75", legend=False, figsize=(8,4))
ax.set_ylabel("Illustrative priority")
ax.set_title("Continuity dashboard — synthetic governance view")
plt.xticks(rotation=25, ha="right"); plt.tight_layout(); plt.show()
print("Governance gate: investigate and obtain accountable human approval before action.")

# %% [markdown]
# # Conclusion
#
# This notebook has converted *Incident Response and Business Continuity in the Age of Agentic AI* from a conceptual chapter into a governed analytical workflow. Across ten exercises, the emphasis remained on containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity. The models were intentionally small and transparent. Their value lies less in predictive sophistication than in making assumptions, dependencies, control effects, and decision boundaries visible. That is the proper starting point for institutional cybersecurity: clarity before complexity, accountability before autonomy, and evidence before action.
#
# The governance-first method changes how results should be read. A score, alert, ranking, or scenario is not a self-executing instruction. It is evidence presented to an accountable decision process. Before production use, an institution must identify the owner, permissible purpose, data lineage, validation standard, authority limit, escalation threshold, independent reviewer, logging requirement, and recovery mechanism. Where a decision can move money, change access, interrupt a service, affect a client, or alter a regulated record, deterministic gates and explicit approval must constrain AI-assisted analysis.
#
# The exercises also demonstrate why AI creates a dual challenge. Frontier models and agentic teams can increase threat speed, scale, persistence, coordination, and adaptability. At the same time, governed defensive agents can help correlate evidence, prioritize attention, simulate stress, and improve response time. The distinction is not simply model quality. It is architecture and governance: permissions, tool boundaries, memory controls, monitoring, segregation of duties, value and time limits, independent verification, and the ability to stop or recover safely.
#
# For finance professionals, cyber risk becomes meaningful through financial transmission channels. Identity failure, data corruption, application outage, weak detection, compromised recovery, or third-party concentration can reach payments, trading, valuation, liquidity, custody, client trust, capital, and regulatory obligations. Therefore, control prioritization should combine technical evidence with business criticality and recoverability. Institutions should resist false precision, test ranges of assumptions, retain tail scenarios, and disclose uncertainty to decision makers.
#
# The next step is not to connect these cells directly to live systems. It is to review them with business, risk, compliance, audit, technology, security, privacy, and legal stakeholders; define an approved use case; validate data and thresholds; and pilot inside a controlled environment. Keep humans responsible for consequential decisions and keep immutable evidence of inputs, outputs, approvals, overrides, and outcomes. Rehearse failure, compromise, and rollback.
#
# The enduring lesson is that cybersecurity in the age of AI is an institutional design problem. Capability without authority design creates exposure. Automation without observability creates opacity. Detection without response rights creates delay. Recovery without trusted evidence creates uncertainty. Governance first unites these elements into a coherent system: understand the business objective, govern the authority and evidence, then create the analytical or autonomous capability. That sequence allows finance institutions to use AI defensively while preserving accountability, resilience, and trust.
#
# The analysis remains anchored in containment, eradication, recovery, reconciliation, decision rights, immutable evidence, kill switches, and resilient continuity, and every result must be interpreted as decision support rather than as permission for an automated action.
#
# A governance-first institution records assumptions, ownership, evidence, approval thresholds, and escalation routes before it relies on a numerical output.
